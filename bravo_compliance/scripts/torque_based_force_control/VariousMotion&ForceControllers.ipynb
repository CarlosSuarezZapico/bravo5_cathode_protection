# %% [markdown]
# ## Controllers for motion and contact control

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 0. Performs a nonlinear compensating action of joint space gravitational forces and an operational space linear PD control action.
# 1. The controller is meant to track a desired end-effector position
# 2. Kd is positive definite and this term is used as a damping term
# 3. Stable in the sense of Lyapunov (at least assuming J full rank)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Compliance Control or Stiffness Control

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $K_p$ is stiffness matrix whereas the inverse $K_p^{-1}$ is the compliance matrix

# %% [markdown]
#  $\dot{q} \rightarrow [v; \omega]$

# %% [markdown]
# # IMPEDANCE CONTROL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# A parallel force/position controller could be a good alternative to our approach. A position controll that governs during free motion and the force reference that takes over during constrained motion.
