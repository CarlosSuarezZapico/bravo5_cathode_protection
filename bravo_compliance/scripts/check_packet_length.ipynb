# %%
from bpl_msgs.msg import Packet, JointPosition, Generic, Packet, SingleFloat
from bplprotocol import PacketReader, BPLProtocol, PacketID
import struct
# Out:
# The kernel failed to start due to the missing module 'psutil'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
BPLProtocol.encode_floats([10.1])
# Out:
# b'\x9a\x99!A'

# %%
position = [10.1]

# %%
data = struct.pack('%sf' % len(position), *position)

# %%
data
# Out:
# b'\x9a\x99!A'

# %%
packet_position = BPLProtocol.encode_packet(0xFF, int(PacketID.REQUEST), [PacketID.POSITION])

# %%
packet_position
# Out:
# b'\x06\x03`\xff\x05\x1b\x00'

# %%
len(packet_position)
# Out:
# 7

# %%
packet_force = BPLProtocol.encode_packet(13, int(PacketID.REQUEST), [PacketID.ATI_FT_READING])

# %%
packet_force
# Out:
# b'\x06\xd8`\r\x05\xba\x00'

# %%
len(packet_force)
# Out:
# 7

# %%
packet_local_velocity = BPLProtocol.encode_packet(0x0E, PacketID.KM_END_VEL_LOCAL, BPLProtocol.encode_floats([0.0, 0.0, 0.0, 1.0, 1.0 ,1.0]))
packet_local_velocity
# Out:
# b'\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x01\x03\x80?\x01\x03\x80?\x01\x07\x80?\xcb\x0e\x1c\xd2\x00'

# %%
len(packet_local_velocity)
# Out:
# 30

# %%
packet_joint_vel = BPLProtocol.encode_packet(0, PacketID.VELOCITY, BPLProtocol.encode_floats([20000]))
packet_joint_vel
# Out:
# b'\x01\x05@\x9cF\x02\x03\x08\xd5\x00'

# %%
len(packet_joint_vel)
# Out:
# 10

# %%
BPLProtocol.encode_packet(0, PacketID.VELOCITY, BPLProtocol.encode_floats([-10.2223243876327863849726312897632154127352512863512673]))
# Out:
# b'\x06\xa4\x8e#\xc1\x02\x03\x08]\x00'

# %%
BPLProtocol.encode_packet(2, PacketID.VELOCITY, BPLProtocol.encode_floats([0.2]))
# Out:
# b'\t\xcd\xccL>\x02\x02\x08\xda\x00'

# %%
packet
# Out:
# b'\x06\xa4\x8e#\xc1\x02\x03\x08]\x00'

# %%
len(packet)
# Out:
# 10

# %%
type(packet)
# Out:
# bytes

# %%
import sys

# %%
sys.getsizeof(packet)
# Out:
# 43

# %%
len(packet)
# Out:
# 10

# %%
packets = b''

# %%
packets += BPLProtocol.encode_packet(0xFF, int(PacketID.REQUEST), [PacketID.POSITION]) 
packets += BPLProtocol.encode_packet(13, int(PacketID.REQUEST), [PacketID.ATI_FT_READING])

# %%
packets
# Out:
# b'\x06\x03`\xff\x05\x1b\x00\x06\xd8`\r\x05\xba\x00'

# %%
len(packets)
# Out:
# 14

# %%
packets = b''

# %%
packets[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X32sdW50aXRsZWQ%3D?line=0'>1</a> packets[0] = 1
#
# TypeError: 'bytes' object does not support item assignment

# %%
			encoded_packet = BPLProtocol.encode_packet(0x0E, PacketID.LOCAL_VELOCITY, BPLProtocol.encode_floats(self.data_local_velocity))
			encoded_packetForce = BPLProtocol.encode_packet(0x0D, PacketID.REQUEST_PACKET, [PacketID.FORCETORQUE])
